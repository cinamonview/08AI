# %%
import pandas as pd
import numpy as np

# 데이터 불러오기
df = pd.read_csv("../data/raw/used_cars_data.csv")
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_19464\924595469.py:5: DtypeWarning: Columns (0: dealer_zip) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/used_cars_data.csv")

# %%
df.shape
# Out:
# (3000040, 66)

# %%
df.columns.tolist()
# Out:
# ['vin',
#  'back_legroom',
#  'bed',
#  'bed_height',
#  'bed_length',
#  'body_type',
#  'cabin',
#  'city',
#  'city_fuel_economy',
#  'combine_fuel_economy',
#  'daysonmarket',
#  'dealer_zip',
#  'description',
#  'engine_cylinders',
#  'engine_displacement',
#  'engine_type',
#  'exterior_color',
#  'fleet',
#  'frame_damaged',
#  'franchise_dealer',
#  'franchise_make',
#  'front_legroom',
#  'fuel_tank_volume',
#  'fuel_type',
#  'has_accidents',
#  'height',
#  'highway_fuel_economy',
#  'horsepower',
#  'interior_color',
#  'isCab',
#  'is_certified',
#  'is_cpo',
#  'is_new',
#  'is_oemcpo',
#  'latitude',
#  'length',
#  'listed_date',
#  'listing_color',
#  'listing_id',
#  'longitude',
#  'main_picture_url',
#  'major_options',
#  'make_name',
#  'maximum_seating',
#  'mileage',
#  'model_name',
#  'owner_count',
#  'power',
#  'price',
#  'salvage',
#  'savings_amount',
#  'seller_rating',
#  'sp_id',
#  'sp_name',
#  'theft_title',
#  'torque',
#  'transmission',
# ...

# %%
for i, col in enumerate(df.columns):
    print(f"{i:2d}. {col}")
# Out:
#  0. vin
#  1. back_legroom
#  2. bed
#  3. bed_height
#  4. bed_length
#  5. body_type
#  6. cabin
#  7. city
#  8. city_fuel_economy
#  9. combine_fuel_economy
# 10. daysonmarket
# 11. dealer_zip
# 12. description
# 13. engine_cylinders
# 14. engine_displacement
# 15. engine_type
# 16. exterior_color
# 17. fleet
# 18. frame_damaged
# 19. franchise_dealer
# 20. franchise_make
# 21. front_legroom
# 22. fuel_tank_volume
# 23. fuel_type
# 24. has_accidents
# 25. height
# 26. highway_fuel_economy
# 27. horsepower
# 28. interior_color
# 29. isCab
# 30. is_certified
# 31. is_cpo
# 32. is_new
# 33. is_oemcpo
# 34. latitude
# 35. length
# 36. listed_date
# 37. listing_color
# 38. listing_id
# 39. longitude
# 40. main_picture_url
# 41. major_options
# 42. make_name
# 43. maximum_seating
# 44. mileage
# 45. model_name
# 46. owner_count
# 47. power
# 48. price
# 49. salvage
# 50. savings_amount
# 51. seller_rating
# 52. sp_id
# 53. sp_name
# 54. theft_title
# 55. torque
# 56. transmission
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000040 entries, 0 to 3000039
# Data columns (total 66 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   vin                      str
#  1   back_legroom             str
#  2   bed                      str
#  3   bed_height               str
#  4   bed_length               str
#  5   body_type                str
#  6   cabin                    str
#  7   city                     str
#  8   city_fuel_economy        float64
#  9   combine_fuel_economy     float64
#  10  daysonmarket             int64
#  11  dealer_zip               object
#  12  description              str
#  13  engine_cylinders         str
#  14  engine_displacement      float64
#  15  engine_type              str
#  16  exterior_color           str
#  17  fleet                    object
#  18  frame_damaged            object
#  19  franchise_dealer         bool
#  20  franchise_make           str
#  21  front_legroom            str
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# is_certified               3000040
# combine_fuel_economy       3000040
# vehicle_damage_category    3000040
# bed                        2980472
# cabin                      2936507
#                             ...
# latitude                         0
# listing_color                    0
# sp_name                          0
# savings_amount                   0
# year                             0
# Length: 66, dtype: int64

# %%
df.drop(columns=[
    "is_certified",
    "combine_fuel_economy",
    "vehicle_damage_category"
], inplace=True)

# %%
df.price.describe()
# Out:
# count    3.000040e+06
# mean     2.993337e+04
# std      1.956617e+04
# min      1.650000e+02
# 25%      1.845100e+04
# 50%      2.647700e+04
# 75%      3.822000e+04
# max      3.299995e+06
# Name: price, dtype: float64

# %%
df.nlargest(10, "price")[["make", "model", "year", "price"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.nlargest(10, "price")[["make", "model", "year", "price"]]
#
# File c:\01Developkits\miniconda3\envs\myvenv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\01Developkits\miniconda3\envs\myvenv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
for col in df.columns:
    if "make" in col.lower():
        print(col)
# Out:
# franchise_make
# make_name

# %%
for col in df.columns:
    if "model" in col.lower():
        print(col)
# Out:
# model_name

# %%
df.nlargest(10, "price")[["make_name", "model_name", "year", "price"]]
# Out:
#              make_name    model_name  year      price
# 1410578        Ferrari          Enzo  2003  3299995.0
# 174408         Ferrari          Enzo  2003  3195000.0
# 2786672        Ferrari     LaFerrari  2014  2749950.0
# 2795480        Ferrari     LaFerrari  2015  2738900.0
# 230048            Ford          Edge  2018  2698500.0
# 2178397      Chevrolet        Impala  2020  2250000.0
# 174397          Pagani        Huayra  2014  2195000.0
# 2178384         Nissan   Rogue Sport  2020  2175000.0
# 2862805     Koenigsegg  CCXR Trevita  2010  2000000.0
# 2057024  Mercedes-Benz     500-Class  1935  1995900.0

# %%
df["make_name"].value_counts().head(20)
# Out:
# make_name
# Ford             476336
# Chevrolet        376892
# Toyota           239128
# Nissan           217896
# Honda            214459
# Jeep             168434
# Hyundai          136097
# Kia              112330
# RAM              102545
# GMC               99293
# Dodge             91376
# Volkswagen        76092
# Subaru            69729
# Mercedes-Benz     66649
# Buick             64786
# BMW               62196
# Mazda             53754
# Cadillac          47166
# Lexus             40646
# Chrysler          36397
# Name: count, dtype: int64

# %%
df["make_name"].nunique()
# Out:
# 100
